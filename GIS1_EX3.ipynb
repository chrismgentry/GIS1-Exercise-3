# %% [markdown]
# # Exercise 3: Editing Map Aesthetics
# ## Geographic Information Systems 1 Lab
# ### GEOG 3150

# %% [markdown]
# Remember to begin each exercise by creating a copy of this _colab notebook_ by going to **File > Save a copy in Drive**. Once you have a copy, go to **Runtime > Run all** to make sure you are connected and each cell of the exercise has been executed. Refer back to the [Exercise 2 Notebook](https://githubtocolab.com/chrismgentry/GIS1-Exercise-2/blob/main/GIS1_EX2.ipynb) for a refresher on how to work with **text cells**, **code cells**, and using the **Share** button at the top of the page.

# %% [markdown]
# # Information
#
# #### Before beginning the exercise be sure to thoroughly read the the exercise page on [GitHub](https://chrismgentry.github.io/GIS1-Exercise-3). This will provide additional information not covered in this notebook. It would be beneficial to have both windows open so you can refer back to the exercise at any time while working on this notebook. Throughout this notebook there will be various code cells and text cells you may need to edit. Simply double-click on the cell to open it for editing.

# %% [markdown]
# Atypical information regarding the _ggsn package_:<br>
# "Due to a dependency issue, the following script had to be used to ensure that the _ggsn_ package would load correctly for this exercise."

# %%
system('sudo add-apt-repository ppa:ubuntugis/ubuntugis-unstable')
system('sudo apt-get update')
system('sudo apt-get install libudunits2-dev libgdal-dev libgeos-dev libproj-dev')

# %% [markdown]
# Atypical information regarding the _ggsn package_:<br>
# "In order to install the _tigris_ package for this exercise you will need to use _developers tools_ to connect directly to the installation file."

# %%
devtools::install_github('walkerke/tigris')
# Out:
# Downloading GitHub repo walkerke/tigris@HEAD
# pillar   (1.6.0 -> 1.6.1 ) [CRAN]
# proxy    (NA    -> 0.4-25) [CRAN]
# e1071    (NA    -> 1.7-6 ) [CRAN]
# tibble   (3.1.1 -> 3.1.2 ) [CRAN]
# units    (NA    -> 0.7-1 ) [CRAN]
# classInt (NA    -> 0.4-3 ) [CRAN]
# openssl  (1.4.3 -> 1.4.4 ) [CRAN]
# sp       (NA    -> 1.4-5 ) [CRAN]
# stringi  (1.5.3 -> 1.6.2 ) [CRAN]
# dplyr    (1.0.5 -> 1.0.6 ) [CRAN]
# sf       (NA    -> 0.9-8 ) [CRAN]
# maptools (NA    -> 1.1-1 ) [CRAN]
# rgdal    (NA    -> 1.5-23) [CRAN]
# Installing 13 packages: pillar, proxy, e1071, tibble, units, classInt, openssl, sp, stringi, dplyr, sf, maptools, rgdal
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ✔  checking for file ‘/tmp/RtmpesEZSL/remotes3ccf0a39a/walkerke-tigris-897cc2c/DESCRIPTION’
# ─  preparing ‘tigris’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘tigris_1.4.0.9000.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# # Step One: The Data
# The following steps will take you through the loading of packages, linking to the data, obtaining state information, and viewing datasets.

# %% [markdown]
# ### Installing and loading packages

# %%
install.packages('ggsn')
install.packages('maps')
library('ggsn')
library('maps')
library("tidyverse")
library("tigris")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘RgoogleMaps’, ‘plyr’, ‘rjson’, ‘jpeg’, ‘bitops’, ‘png’, ‘ggmap’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: ggplot2
#
# Loading required package: grid
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ purrr::map()    masks maps::map()
#
# To enable
# caching of data, set `options(tigris_use_cache = TRUE)` in your R script or .Rprofile.

# %% [markdown]
# ### Connecting to and viewing the census tract data

# %%
montco_tracts <- tracts("TN", county = "Montgomery")
# Out:
#   |======================================================================| 100%

# %% [markdown]
# Due to the inability to load the ```geojsonio``` package, there will be an error preceeding the displayed data. Scroll down to view the information contained in the dataset.

# %%
montco_tracts
# Out:
# ERROR while rich displaying an object: Error in loadNamespace(name): there is no package called ‘geojsonio’
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_geojson.sf(obj)
# 9. repr_geojson(geojsonio::geojson_list(obj), ...)
# 10. geojsonio::geojson_list
# 11. getExportedValue(pkg, name)
# 12. asNamespace(ns)
# 13. getNamespace(ns)
# 14. loadNamespace(name)
# 15. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 16. withOneRestart(expr, restarts[[1L]])
# 17. doWithOneRestart(return(expr), restart)
#      STATEFP COUNTYFP TRACTCE GEOID       NAME    NAMELSAD             MTFCC
# 149  47      125      980100  47125980100 9801    Census Tract 9801    G5020
# 150  47      125      101804  47125101804 1018.04 Census Tract 1018.04 G5020
# 151  47      125      101903  47125101903 1019.03 Census Tract 1019.03 G5020
# 152  47      125      101904  47125101904 1019.04 Census Tract 1019.04 G5020
# 153  47      125      101306  47125101306 1013.06 Census Tract 1013.06 G5020
# 154  47      125      101305  47125101305 1013.05 Census Tract 1013.05 G5020
# 155  47      125      102002  47125102002 1020.02 Census Tract 1020.02 G5020
# 218  47      125      100200  47125100200 1002    Census Tract 1002    G5020
# 219  47      125      100602  47125100602 1006.02 Census Tract 1006.02 G5020
# 293  47      125      100700  47125100700 1007    Census Tract 1007    G5020
# 294  47      125      100800  47125100800 1008    Census Tract 1008    G5020
# 295  47      125      101101  47125101101 1011.01 Census Tract 1011.01 G5020
# 296  47      125      101002  47125101002 1010.02 Census Tract 1010.02 G5020
# 330  47      125      100601  47125100601 1006.01 Census Tract 1006.01 G5020
# 331  47      125      101902  47125101902 1019.02 Census Tract 1019.02 G5020
# 332  47      125      102006  47125102006 1020.06 Census Tract 1020.06 G5020
# 333  47      125      101307  47125101307 1013.07 Census Tract 1013.07 G5020
# 336  47      125      101202  47125101202 1012.02 Census Tract 1012.02 G5020
# 337  47      125      101303  47125101303 1013.03 Census Tract 1013.03 G5020
# 338  47      125      102005  47125102005 1020.05 Census Tract 1020.05 G5020
# 339  47      125      102003  47125102003 1020.03 Census Tract 1020.03 G5020
# 365  47      125      100400  47125100400 1004    Census Tract 1004    G5020
# 418  47      125      101500  47125101500 1015    Census Tract 1015    G5020
# 419  47      125      101103  47125101103 1011.03 Census Tract 1011.03 G5020
# 420  47      125      100900  47125100900 1009    Census Tract 1009    G5020
# 421  47      125      101102  47125101102 1011.02 Census Tract 1011.02 G5020
# 422  47      125      101802  47125101802 1018.02 Census Tract 1018.02 G5020
# 423  47      125      101600  47125101600 1016    Census Tract 1016    G5020
# 424  47      125      101700  47125101700 1017    Census Tract 1017    G5020
# 425  47      125      101400  47125101400 1014    Census Tract 1014    G5020
# 426  47      125      100100  47125100100 1001    Census Tract 1001    G5020
# 427  47      125      100500  47125100500 1005    Census Tract 1005    G5020
# 1125 47      125      102004  47125102004 1020.04 Census Tract 1020.04 G5020
# 1126 47      125      101803  47125101803 1018.03 Census Tract 1018.03 G5020
# 1343 47      125      101001  47125101001 1010.01 Census Tract 1010.01 G5020
# 1344 47      125      100300  47125100300 1003    Census Tract 1003    G5020
# 1347 47      125      102001  47125102001 1020.01 Census Tract 1020.01 G5020
# 1348 47      125      101201  47125101201 1012.01 Census Tract 1012.01 G5020
# 1349 47      125      101304  47125101304 1013.04 Census Tract 1013.04 G5020
#      FUNCSTAT ALAND     AWATER  INTPTLAT    INTPTLON
# 149  S        156319317  185782 +36.5918548 -087.5496662
# 150  S         72477337  266605 +36.5159417 -087.1787721
# 151  S         27483220  205583 +36.5601919 -087.2763298
# 152  S        107599134   92813 +36.5832431 -087.1920783
# 153  S          6158019       0 +36.5922151 -087.3933071
# 154  S         15914306       0 +36.6111459 -087.3870708
# 155  S         15464578       0 +36.5962889 -087.3388070
# 218  S          2554805  196351 +36.5152365 -087.3641748
# 219  S          2710186       0 +36.5171937 -087.2924598
# 293  S          2299817       0 +36.5271978 -087.3340849
# 294  S          3919141  109229 +36.5369468 -087.3542982
# 295  S          2301120       0 +36.5677048 -087.4117097
# 296  S          7332810       0 +36.5719960 -087.3718967
# 330  S          6613313    5314 +36.5248983 -087.3062545
# 331  S          7361273       0 +36.5401941 -087.3125457
# 332  S         26713521   21629 +36.6270078 -087.2634607
# 333  S          1904706       0 +36.5817502 -087.4007817
# 336  S          7522623       0 +36.5871778 -087.4385433
# 337  S          7390684     761 +36.6363089 -087.3994510
# 338  S         12044478       0 +36.6013807 -087.3043063
# 339  S          7046270       0 +36.6201653 -087.3445281
# 365  S          3871787   61432 +36.5106265 -087.3370940
# 418  S        178801127 2715791 +36.4938519 -087.5283139
# 419  S         13573843  227058 +36.5321104 -087.4240761
# 420  S          7445598  241424 +36.5486263 -087.3721135
# 421  S         14065116   24254 +36.5588398 -087.4377024
# 422  S        136430472 1092361 +36.4499522 -087.2425710
# 423  S         83542568 2694274 +36.4747906 -087.3843419
# 424  S        362665465 3314576 +36.4009109 -087.4253181
# 425  S         18356047       0 +36.6193887 -087.4549314
# 426  S          1210603   77472 +36.5275467 -087.3558995
# 427  S          7447849  167664 +36.5063974 -087.3060324
# 1125 S          6831608    3472 +36.6356004 -087.3413280
# 1126 S         25898355   15392 +36.4960535 -087.1952491
# 1343 S          4156725       0 +36.5654174 -087.3938295
# 1344 S         10757537  360726 +36.4962685 -087.3608859
# 1347 S         13737362       0 +36.5645258 -087.3336690
# 1348 S          2440091       0 +36.5783393 -087.4255501
# 1349 S          6067786       0 +36.6192239 -087.4208846
#      geometry
# 149  MULTIPOLYGON (((-87.64116 3...
# 150  MULTIPOLYGON (((-87.28235 3...
# 151  MULTIPOLYGON (((-87.3226 36...
# 152  MULTIPOLYGON (((-87.28141 3...
# 153  MULTIPOLYGON (((-87.42227 3...
# 154  MULTIPOLYGON (((-87.42473 3...
# 155  MULTIPOLYGON (((-87.36957 3...
# 218  MULTIPOLYGON (((-87.37856 3...
# 219  MULTIPOLYGON (((-87.31279 3...
# 293  MULTIPOLYGON (((-87.34857 3...
# 294  MULTIPOLYGON (((-87.37099 3...
# 295  MULTIPOLYGON (((-87.42973 3...
# 296  MULTIPOLYGON (((-87.39171 3...
# 330  MULTIPOLYGON (((-87.32434 3...
# 331  MULTIPOLYGON (((-87.33451 3...
# 332  MULTIPOLYGON (((-87.3169 36...
# 333  MULTIPOLYGON (((-87.41221 3...
# 336  MULTIPOLYGON (((-87.46656 3...
# 337  MULTIPOLYGON (((-87.43659 3...
# 338  MULTIPOLYGON (((-87.32041 3...
# 339  MULTIPOLYGON (((-87.37297 3...
# 365  MULTIPOLYGON (((-87.34827 3...
# 418  MULTIPOLYGON (((-87.62611 3...
# 419  MULTIPOLYGON (((-87.45464 3...
# 420  MULTIPOLYGON (((-87.40088 3...
# 421  MULTIPOLYGON (((-87.47758 3...
# 422  MULTIPOLYGON (((-87.30973 3...
# 423  MULTIPOLYGON (((-87.46609 3...
# 424  MULTIPOLYGON (((-87.6026 36...
# 425  MULTIPOLYGON (((-87.497 36....
# 426  MULTIPOLYGON (((-87.36541 3...
# 427  MULTIPOLYGON (((-87.33035 3...
# 1125 MULTIPOLYGON (((-87.36961 3...
# 1126 MULTIPOLYGON (((-87.27307 3...
# 1343 MULTIPOLYGON (((-87.40776 3...
# 1344 MULTIPOLYGON (((-87.38317 3...
# 1347 MULTIPOLYGON (((-87.36262 3...
# 1348 MULTIPOLYGON (((-87.44549 3...
# 1349 MULTIPOLYGON (((-87.43415 3...

# %% [markdown]
# ### Displaying the census tracts

# %% [markdown]
# In the previous exercise we used the `ggplot2` package to create a graphical display of the information. Various geometries were discussed including **geom_polygon** and **geom_point**. The `tigris` package uses an object called **geom_sf** which stands for _simple features_. This data type is discussed further on the _GitHub_ [exercise page](https://chrismgentry.github.io/GIS1-Exercise-2/), but will need to be added to the _ggplot_ script in order for the information to be displayed appropriately.

# %%
ggplot(data = montco_tracts) + geom_sf()
# Out:
# plot without title

# %% [markdown]
# ## **Question No. 1**
# If you were interested in obtaining information for the census tracts around _Nashville_, how would you alter the code above?<br>
# _Answer in the code cell below._

# %% [markdown]
# ### **ANSWER**:

# %% [markdown]
# # Step Two: The Analyses
# In this step you will organize and display the data in order to prepare it for the final visualization.

# %% [markdown]
# ### Obtaining the population data

# %%
population <- read.csv('https://raw.githubusercontent.com/chrismgentry/GIS1-Exercise-3/main/Data/mont_co_pop.csv', 
                        colClasses=c(Tract="character"))
head(population)
# Out:
#   Tract   total_pop male female under_5yo age5_9yo age10_14yo age15_19yo
# 1 1001    1162       621  541     0         0       32         24
# 2 1002    1503       728  775    71        41      104        166
# 3 1003    5549      2621 2928   453       629      463        214
# 4 1004    3077      1598 1479   309       260      140        208
# 5 1005    4601      2259 2342   459       208       99        238
# 6 1006.01 2188      1032 1156    88       145      109        115
#   age5_18yo age20_24yo age25_34yo age35_44yo age45_54yo age55_59yo age60_64yo
# 1   38      268         404       229         93         68          7
# 2  256      118         261       181        179        128         89
# 3 1269      272         951       655        659        250        358
# 4  485      203         580       501        273        204        126
# 5  397      472        1158       523        207        158        342
# 6  331       81         257       234        247        144        130
#   age65_74yo age75_84yo age85_over
# 1  37          0          0
# 2 105         55          5
# 3 397        148        100
# 4 174         57         42
# 5 361        166        210
# 6 342        198         98

# %% [markdown]
# **Be sure to examine the different variables in the dataset so you will be familiar with them for future analyses.**

# %% [markdown]
# ### Merging the census tracts and population data

# %% [markdown]
# Because of the issues with the `geojsonio` package, there will again be an error when viewing this data. It does not affect your ability to use or analyze the information. Please scroll down to see the data.

# %%
tract_pop <- merge(x = montco_tracts, y = population, by.x = "NAME", by.y = "Tract", all = TRUE)
head(tract_pop)
# Out:
# ERROR while rich displaying an object: Error in loadNamespace(name): there is no package called ‘geojsonio’
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_geojson.sf(obj)
# 9. repr_geojson(geojsonio::geojson_list(obj), ...)
# 10. geojsonio::geojson_list
# 11. getExportedValue(pkg, name)
# 12. asNamespace(ns)
# 13. getNamespace(ns)
# 14. loadNamespace(name)
# 15. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 16. withOneRestart(expr, restarts[[1L]])
# 17. doWithOneRestart(return(expr), restart)
#   NAME    STATEFP COUNTYFP TRACTCE GEOID       NAMELSAD             MTFCC
# 1 1001    47      125      100100  47125100100 Census Tract 1001    G5020
# 2 1002    47      125      100200  47125100200 Census Tract 1002    G5020
# 3 1003    47      125      100300  47125100300 Census Tract 1003    G5020
# 4 1004    47      125      100400  47125100400 Census Tract 1004    G5020
# 5 1005    47      125      100500  47125100500 Census Tract 1005    G5020
# 6 1006.01 47      125      100601  47125100601 Census Tract 1006.01 G5020
#   FUNCSTAT ALAND    AWATER geometry                       ⋯ age20_24yo
# 1 S         1210603  77472 MULTIPOLYGON (((-87.36541 3... ⋯ 268
# 2 S         2554805 196351 MULTIPOLYGON (((-87.37856 3... ⋯ 118
# 3 S        10757537 360726 MULTIPOLYGON (((-87.38317 3... ⋯ 272
# 4 S         3871787  61432 MULTIPOLYGON (((-87.34827 3... ⋯ 203
# 5 S         7447849 167664 MULTIPOLYGON (((-87.33035 3... ⋯ 472
# 6 S         6613313   5314 MULTIPOLYGON (((-87.32434 3... ⋯  81
#   age25_34yo age35_44yo age45_54yo age55_59yo age60_64yo age65_74yo age75_84yo
# 1  404       229         93         68          7         37          0
# 2  261       181        179        128         89        105         55
# 3  951       655        659        250        358        397        148
# 4  580       501        273        204        126        174         57
# 5 1158       523        207        158        342        361        166
# 6  257       234        247        144        130        342        198
#   age85_over geometry
# 1   0        MULTIPOLYGON (((-87.36541 3...
# 2   5        MULTIPOLYGON (((-87.37856 3...
# 3 100        MULTIPOLYGON (((-87.38317 3...
# 4  42        MULTIPOLYGON (((-87.34827 3...
# 5 210        MULTIPOLYGON (((-87.33035 3...
# 6  98        MULTIPOLYGON (((-87.32434 3...

# %% [markdown]
# Remember due to the ```geojsonio``` issue, there will be an error preceeding the displayed data.

# %% [markdown]
# ### Quick plot of the census tracts and population data

# %% [markdown]
# Remeber that **geom_sf** must be included in the script to visualize the data based on the _simple features_ format.

# %%
ggplot() + geom_sf(data = tract_pop, aes(fill = total_pop))
# Out:
# plot without title

# %% [markdown]
# ### Obtaining the CMCSS schools data

# %%
schools <- read.csv('https://raw.githubusercontent.com/chrismgentry/GIS1-Exercise-3/main/Data/county_schools.csv')
head(schools)
# Out:
#   SCHOOL_NAM                X         Y        LEVEL ADDRESS
# 1 Board of Education        -87.34497 36.52043 0     621 Gracey Avenue
# 2 Greenwood Complex         -87.34854 36.52312 0     430 Greenwood Avenue
# 3 Learning Center           -87.33902 36.51923 0     343 Pageant Lane
# 4 Maintenance Department    -87.25789 36.50434 0     2620 Highway 41-A South
# 5 Transportation Department -87.25821 36.50369 0     2620 Highway 41-A South
# 6 Barkers Mill Elementary   -87.38508 36.62552 1     1230 Little Bobcat Road
#   CITY        STATE ZIP_CODE PHONE_NUMB ENROLLMENT
# 1 Clarksville TN    37040    648-5600     0
# 2 Clarksville TN    37040    648-5650     0
# 3 Clarksville TN    37040    648-5653     0
# 4 Clarksville TN    37043    358-4089     0
# 5 Clarksville TN    37043    358-4089     0
# 6 Clarksville TN    37042    906-7235   993

# %% [markdown]
# ### Creating the data point for the _new school_.

# %%
new_school <- data.frame(x  = -87.19495519624655, y = 36.56793328339189, name = "New School")
head(new_school)
# Out:
#   x         y        name
# 1 -87.19496 36.56793 New School

# %% [markdown]
# ## **Question No. 2**
# Just as **\<-** can be used to create an object, **\$** can be used after an object to examine a specific variable within the dataset. For example ```summary(tract_pop$total_pop)``` can be used to summarize the total population variable.
# <blockquote>
# Using the example above, replace the variable and answer the following question: What is the maximum number of males and females in the dataset?
# </blockquote>

# %% [markdown]
# ### **ANSWER**:

# %% [markdown]
# # Step Three: The Visualization
# You will now create a graphical display of your data that includes cartographic elements such as legend, scale bar, north arrow, etc.

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# Using **theme_minimal()** allows you to view the longitude and latitude values which will be beneficial when trying to place the various elements. To finalize the map you should change to **theme_void()** to remove the grid and coordinates.

# %%
ggplot() + 
  geom_sf(data = tract_pop, aes(fill = age5_18yo), color = "white") +
  scale_fill_viridis_c(option = "D", "No. of Children") +
  geom_point(data = schools, aes(x=X, y=Y), size = 3, shape = 21,
             fill = "black", color = "white") +
  geom_point(data = new_school, aes(x=x, y=y), shape = 8, size = 5,
             color = "red") +
  north(tract_pop, location = "bottomleft", scale = 0.05, symbol = 12, anchor = c(x=-87.15, y=36.31)) + 
  scalebar(tract_pop, dist = 5, dist_unit = "mi", transform = TRUE,
           model = "WGS84", location = "bottomleft",
           st.dist = 0.02, st.size = 2, anchor = c(x= -87.65, y= 36.31)) +
  annotate("text", x = -87.22, y = 36.35, label = "Chris Gentry\n August 2021", size = 2) +
  labs(title = "School Aged Children per Census Tract and CMCSS Locations") +
  geom_text(data = new_school, aes(x=x,y=y, label = name), nudge_y = 0.025, nudge_x = 0.0, color = "white") +
  theme_void()
# Out:
# plot without title

# %%
tn <- map_data('county', region = "tennessee")
states <- map_data('state')

# %%
ggplot() + 
  geom_polygon(data = states, aes(x=long, y=lat, group=group), fill = "darkgray", color = "white") +
  geom_polygon(data = tn, aes(x=long, y=lat, group=group), fill = "lightgray", color = "white") +
  geom_sf(data = tract_pop, aes(fill = under_5yo)) +
  scale_fill_viridis_c("Children Aged 0-5", limits = c(0,1400), breaks = c(0,700,1400)) + 
  geom_jitter(data = schools, aes(x=X, y=Y, size = ENROLLMENT), shape = 21, 
              width = 0.01, height = 0.01, fill = "black", color = "white", alpha = 0.5) +
  geom_point(data = new_school, aes(x=x, y=y,), shape = 8, size = 6, color = "red") +
  scale_size_continuous("Approximate Enrollment", limits = c(0,2000), breaks = c(0,500,1000,1500,2000)) +
  theme_void() + labs(title = "Number of Current K-12 Aged Children by Census Tract \nwith Current School Populations") +
  north(tract_pop, location = "bottomleft", scale = 0.05, symbol = 12, anchor = c(x=-87.15, y=36.31)) + 
  scalebar(tract_pop, dist = 5, dist_unit = "mi", transform = TRUE, model = "WGS84", location = "bottomleft", 
           st.dist = 0.03, st.size = 3, anchor = c(x= -87.65, y= 36.31)) +
  annotate("text", x = -87.22, y = 36.35, label = "Chris Gentry\n August 2021", size = 2) +
  coord_sf(xlim = c(-87.65,-87.1), ylim = c(36.30, 36.65)) + 
  geom_text(data = new_school, aes(x=x,y=y, label = name), nudge_y = 0.025, nudge_x = 0.0, color = "white") +
  theme(plot.title = element_text(hjust = 0.5))
# Out:
# plot without title

# %%
ggplot() + 
  geom_polygon(data = states, aes(x=long, y=lat, group=group), fill = "darkgray", color = "white") +
  geom_polygon(data = tn, aes(x=long, y=lat, group=group), fill = "lightgray", color = "white") +
  geom_sf(data = tract_pop, aes(fill = under_5yo)) +
  scale_fill_viridis_c("Children Aged 0-5", limits = c(0,1400), breaks = c(0,700,1400), 
                       guide = guide_colourbar(title.position = "top", title.hjust = 0.5, barwidth = 12, ticks.linewidth = 1, 
                       frame.colour = "white", frame.linewidth = 2, frame.linetype = 1)) + 
  geom_jitter(data = schools, aes(x=X, y=Y, size = ENROLLMENT, color = ENROLLMENT), shape = 16, width = 0.01, height = 0.01) +
  geom_point(data = new_school, aes(x=x, y=y,), shape = 8, size = 6, color = "red") +
  guides(color = guide_legend(title.position = "top", title.hjust = 0.5), size=guide_legend(title.position = "top", title.hjust = 0.5)) +
  scale_colour_viridis_c("Approximate Enrollment", option = "inferno", limits = c(0,2000), breaks = c(0,500,1000,1500,2000)) + 
  scale_size_continuous("Approximate Enrollment", limits = c(0,2000), breaks = c(0,500,1000,1500,2000)) +
  theme_void() + labs(title = "Number of Children Entering School through 2026 by Census Tract \nwith Current School Populations") +
  north(tract_pop, location = "bottomleft", scale = 0.05, symbol = 12, anchor = c(x=-87, y=36.645)) + 
  scalebar(tract_pop, dist = 5, dist_unit = "mi", transform = TRUE, model = "WGS84", location = "bottomleft", 
           st.dist = 0.03, st.size = 3, anchor = c(x= -87.65, y= 36.31)) +
  annotate("text", x = -87.64, y = 36.654, label = "Chris Gentry\n August 2021", size = 2) +
  coord_sf(xlim = c(-87.65,-86.99), ylim = c(36.30, 36.65)) +
  theme(legend.direction = "horizontal", legend.box = "vertical", legend.position = c(0.78, 0.15), legend.box.just = "center", 
        legend.spacing.x = unit(0.05, 'cm'), plot.title = element_text(hjust = 0.5), 
        plot.background = element_rect(fill = "darkgray", color = "white")) + 
  geom_text(data = new_school, aes(x=x,y=y, label = name), nudge_y = 0.025, nudge_x = 0.0, color = "white")
# Out:
# plot without title

# %%
ggplot() + 
  geom_polygon(data = states, aes(x=long, y=lat, group=group), fill = "darkgray", color = "white") +
  geom_polygon(data = tn, aes(x=long, y=lat, group=group), fill = "lightgray", color = "white") +
  geom_sf(data = tract_pop, aes(fill = under_5yo)) +
  scale_fill_viridis_c("Children Aged 0-5", limits = c(0,1400), breaks = c(0,700,1400), 
                       guide = guide_colourbar(title.position = "top", title.hjust = 0.5, barwidth = 12, ticks.linewidth = 1, 
                       frame.colour = "white", frame.linewidth = 2, frame.linetype = 1)) + 
  geom_jitter(data = schools, aes(x=X, y=Y, size = ENROLLMENT), fill = "black", color ="white", shape = 21, width = 0.01, height = 0.01, alpha = 0.5) +
  geom_point(data = new_school, aes(x=x, y=y,), shape = 8, size = 6, color = "red") +
  guides(color = guide_legend(title.position = "top", title.hjust = 0.5), size=guide_legend(title.position = "top", title.hjust = 0.5)) +
#  scale_colour_viridis_c("Approximate Enrollment", option = "inferno", limits = c(0,2000), breaks = c(0,500,1000,1500,2000)) + 
  scale_size_continuous("Approximate Enrollment", limits = c(0,2000), breaks = c(0,500,1000,1500,2000), range = c(2,8)) +
  theme_void() + labs(title = "Number of Children Entering School through 2026 by Census Tract \nwith Current School Populations") +
  north(tract_pop, location = "bottomleft", scale = 0.05, symbol = 12, anchor = c(x=-87, y=36.645)) + 
  scalebar(tract_pop, dist = 5, dist_unit = "mi", transform = TRUE, model = "WGS84", location = "bottomleft", 
           st.dist = 0.03, st.size = 3, anchor = c(x= -87.65, y= 36.31)) +
  annotate("text", x = -87.64, y = 36.654, label = "Chris Gentry\n August 2021", size = 2) +
  coord_sf(xlim = c(-87.65,-86.99), ylim = c(36.30, 36.65)) +
  theme(legend.direction = "horizontal", legend.box = "vertical", legend.position = c(0.78, 0.15), legend.box.just = "center", 
        legend.spacing.x = unit(0.05, 'cm'), plot.title = element_text(hjust = 0.5), 
        plot.background = element_rect(fill = "darkgray", color = "white")) + 
  geom_text(data = new_school, aes(x=x,y=y, label = name), nudge_y = 0.025, nudge_x = 0.0, color = "white")
# Out:
# plot without title

# %% [markdown]
# colors <- c('#440154', '#3a528b', '#20908d', '#5dc962', '#fde725')
